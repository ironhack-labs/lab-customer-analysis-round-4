# %%
import pandas as pd
import numpy as np
clean= pd.read_csv("clean_file1.csv")
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
#Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categorical

# %%
clean.dtypes
# Out:
# Unnamed: 0                         int64
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# ...

# %%
numerical=clean.select_dtypes(include=np.number)

# %%
# categorical2=clean.select_dtypes(include=object) # option 2

# %%
numerical
# Out:
#        Unnamed: 0  customer lifetime value  income  monthly premium auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# ...

# %%
categorical=clean.select_dtypes(exclude=np.number)

# %%
categorical
# Out:
#       customer       state response  coverage education effective to date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location code marital status     policy type  \
# ...

# %%
#Use seaborn library to construct distribution plots for the numerical variables
sns.pairplot(numerical)
plt.show()

# %%
#Use Matplotlib to construct histograms  

	month
sns.histplot(numerical['months since policy inception'],bins=12) 
plt.show()

# %%
sns.histplot(numerical['customer lifetime value'],bins=12) 
plt.show()

# %%
sns.histplot(numerical['income'],bins=12) 
plt.show()

# %%
sns.histplot(numerical['monthly premium auto'],bins=12) 
plt.show()

# %%
sns.histplot(numerical['months since last claim'],bins=12) 
plt.show()

# %%
sns.histplot(numerical['number of open complaints'],bins=12) 
plt.show()

# %%
sns.histplot(numerical['number of policies'],bins=12) 
plt.show()

# %%
sns.histplot(numerical['total claim amount'],bins=12) 
plt.show()

# %%
sns.histplot(numerical['month'],bins=12) 
plt.show()

# %%
#Do the distributions for different numerical variables look like a normal distribution

plt.hist(numerical['total claim amount'])
plt.show()

# None of the variables looks like a normal distribution

# %%
# (doing it again with random values) 
#Do the distributions for different numerical variables look like a normal distribution

# %%
import random 
total_claim2 = np.random.normal(25,10,1000)

# %%
total_claim2

plt.hist(total_claim2)
plt.show()

# %%
#For the numerical variables, check the multicollinearity between the features. 
#Please note that we will use the column total_claim_amount later as the target variable.

sns.heatmap(numerical.corr(),annot=True, annot_kws={"size": 6})
plt.show()

# %%
#Drop one of the two features that show a high correlation between them (greater than 0.9).
    #Not applicable
    
#Write code for both the correlation matrix and for seaborn heatmap.
    #above the code for seaborn heatmap
    

x=numerical['total claim amount'].corr(numerical['monthly premium auto']) 


print("this is the highest correlation :", x)


                               
#If there is no pair of features that have a high correlation, then do not drop any features 
    # :)
# Out:
# this is the highest correlation : 0.6317985607757723
